# %%
# %matplotlib inline

data = [1,2,3,4,5,6,7,7,8,9,10,10,10]
import seaborn as sns

import matplotlib.pyplot as plt 
plt.hist(data,bins=8)
# Out:
# (array([ 2.,  1.,  1.,  1.,  1.,  2.,  1.,  4.]),
#  array([  1.   ,   2.125,   3.25 ,   4.375,   5.5  ,   6.625,   7.75 ,
#           8.875,  10.   ]),
#  <a list of 8 Patch objects>)
